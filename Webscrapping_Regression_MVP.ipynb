# %% [markdown]
# # MVP

# %% [markdown]
# The goal of my project is to build a model that has predictive power for housing prices in the northern NYC suburbs. My data has been compiled primarily from Zillow and Zipmapsdata (for Zipcode level data).
#
# After webscrapping, I have split my data into test and training data. I began with a basic linear regression. Then after feature engineering and transformations, I fit a linear, ridge, and lasso regression (I standardized my data pre-ridge and pre-lasso).
# The two graphs below show 1) the basic linear regression of my model before any feature engineering/transformation and 2) the linear regression after feature engineering and transformation.

# %% [markdown]
# ## Next steps

# %% [markdown]
# My next steps will be tweaking my different models (and features) until I believe this model is meaningful, testing this model on my test data that I have set aside, and then using the prediction on current listed homes to see if there are any 'value' listings

# %%
from IPython.display import Image
Image(filename='Pre.png')

# %%
Image(filename='Post.png')
